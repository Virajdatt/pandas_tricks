# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(np.random.randint(0, 100, size=(15, 4)), columns=list("ABCD"))

# %% [markdown]
# # Coloring cells (by frequencies) is as simple as:
#
# ## * Coloring is column-based

# %%
df.style.background_gradient(cmap="Blues")
# Out:
# <style  type="text/css" >
# #T_6fd82272_bc88_11eb_8a98_9801a79082d5row0_col0{
#             background-color:  #7cb7da;
#             color:  #000000;
#         }#T_6fd82272_bc88_11eb_8a98_9801a79082d5row0_col1,#T_6fd82272_bc88_11eb_8a98_9801a79082d5row1_col2,#T_6fd82272_bc88_11eb_8a98_9801a79082d5row3_col2,#T_6fd82272_bc88_11eb_8a98_9801a79082d5row10_col0,#T_6fd82272_bc88_11eb_8a98_9801a79082d5row13_col3{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_6fd82272_bc88_11eb_8a98_9801a79082d5row0_col2{
#             background-color:  #eff6fc;
#             color:  #000000;
#         }#T_6fd82272_bc88_11eb_8a98_9801a79082d5row0_col3{
#             background-color:  #084e98;
#             color:  #f1f1f1;
#         }#T_6fd82272_bc88_11eb_8a98_9801a79082d5row1_col0{
#             background-color:  #3282be;
#             color:  #000000;
#         }#T_6fd82272_bc88_11eb_8a98_9801a79082d5row1_col1{
#             background-color:  #206fb4;
# ...

# %% [markdown]
# # Other colors that can be used are matplotlibs:-
#
# ## You can set any colormap supported in matplotlib. Just be careful to select the sequential colormap if your goal is to visualize the frequencies.
#
#
# cmaps['Sequential'] = [
#             'Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds',
#             'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu',
#             'GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn']

# %%
df.style.background_gradient(cmap="YlGnBu")
# Out:
# <style  type="text/css" >
# #T_6fdb16bc_bc88_11eb_8a98_9801a79082d5row0_col0{
#             background-color:  #55bec1;
#             color:  #000000;
#         }#T_6fdb16bc_bc88_11eb_8a98_9801a79082d5row0_col1,#T_6fdb16bc_bc88_11eb_8a98_9801a79082d5row1_col2,#T_6fdb16bc_bc88_11eb_8a98_9801a79082d5row3_col2,#T_6fdb16bc_bc88_11eb_8a98_9801a79082d5row10_col0,#T_6fdb16bc_bc88_11eb_8a98_9801a79082d5row13_col3{
#             background-color:  #081d58;
#             color:  #f1f1f1;
#         }#T_6fdb16bc_bc88_11eb_8a98_9801a79082d5row0_col2{
#             background-color:  #f9fdcc;
#             color:  #000000;
#         }#T_6fdb16bc_bc88_11eb_8a98_9801a79082d5row0_col3{
#             background-color:  #22328f;
#             color:  #f1f1f1;
#         }#T_6fdb16bc_bc88_11eb_8a98_9801a79082d5row1_col0{
#             background-color:  #1f78b4;
#             color:  #000000;
#         }#T_6fdb16bc_bc88_11eb_8a98_9801a79082d5row1_col1{
#             background-color:  #225ca7;
# ...
